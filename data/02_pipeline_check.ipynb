# %%
import pandas as pd
import sys
sys.path.insert(0, "..")

from scoring_lib.preprocessing import clean_pipeline
from scoring_lib.features import build_features

# Charger les données brutes
df = pd.read_csv("cs-training.csv")
print("Avant :", df.shape)

# Appliquer le pipeline complet
df_clean = clean_pipeline(df)
print("Après nettoyage :", df_clean.shape)

df_final = build_features(df_clean)
print("Après feature engineering :", df_final.shape)

df_final.head()
# Out:
# Avant : (150000, 12)
# Après nettoyage : (149999, 15)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\soufi\Projects\credit-scoring-platform\venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'times_30_59_days_late'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 16
#      12 # Appliquer le pipeline complet
#      13 df_clean = clean_pipeline(df)
#      14 print("Après nettoyage :", df_clean.shape)
#      15
# ---> 16 df_final = build_features(df_clean)
#      17 print("Après feature engineering :", df_final.shape)
#      18
#      19 df_final.head()
#
# File c:\Users\soufi\Projects\credit-scoring-platform\data\..\scoring_lib\features.py:110, in build_features(df)
#     100 def build_features(df: pd.DataFrame) -> pd.DataFrame:
#     101     """
#     102     Enchaîne toutes les étapes de feature engineering dans l'ordre.
#     103
#    (...)    108         DataFrame enrichi avec les nouvelles features
#     109     """
# --> 110     df = add_total_late_payments(df)
#     111     df = add_max_delinquency_severity(df)
#     112     df = add_credit_lines_per_dependent(df)
#
# File c:\Users\soufi\Projects\credit-scoring-platform\data\..\scoring_lib\features.py:32, in add_total_late_payments(df)
#      15 """
#      16 Calcule le nombre total d'incidents de retard de paiement, tous niveaux
#      17 de gravité confondus (30-59, 60-89, 90+ jours).
#    (...)     28     DataFrame avec une nouvelle colonne 'total_late_payments'
#      29 """
#      30 df = df.copy()
#      31 df["total_late_payments"] = (
# ---> 32     df["times_30_59_days_late"]
#      33     + df["times_60_89_days_late"]
#      34     + df["times_90_days_late"]
#      35 )
#      36 return df
#
# File c:\Users\soufi\Projects\credit-scoring-platform\venv\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File c:\Users\soufi\Projects\credit-scoring-platform\venv\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'times_30_59_days_late'
